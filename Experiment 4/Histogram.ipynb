# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanchithedau/Data_Science_Lab_SE_A_18/blob/main/Experiment%204/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a normal distribution with mean 0 and standard deviation 1
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# Display some of the generated data
print(s[:10])
# Out:
# [ 0.12294288 -0.10628013 -0.04382662  0.28277497 -0.01246154  0.13368302
#   0.10594273  0.13413564 -0.08198016  0.03873756]

# %%
import matplotlib.pyplot as plt

# Create the histogram
count, bins, ignored = plt.hist(s, 30, density=True)

# Plot the probability density function (PDF) for comparison
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')

plt.xlabel('Value')
plt.ylabel('Frequency / Probability Density')
plt.title('Histogram of a Normal Distribution')
plt.grid(True)
plt.show()
